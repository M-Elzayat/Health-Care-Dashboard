# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Patients data
df_patients = pd.read_csv("patients.csv")
print("=== Patients Data ===")
display(df_patients.head())

# Providers data
df_providers = pd.read_csv("providers.csv")
print("=== Providers Data ===")
display(df_providers.head())

# Visits data
df_visits = pd.read_csv("visits.csv")
print("=== Visits Data ===")
display(df_visits.head())

# Cities data
df_cities = pd.read_csv("cities.csv")
print("=== Cities Data ===")
display(df_cities.head())

# Departments data
df_departments = pd.read_csv("departments.csv")
print("=== Departments Data ===")
display(df_departments.head())

# Diagnoses data
df_diagnoses = pd.read_csv("diagnoses.csv")
print("=== Diagnoses Data ===")
display(df_diagnoses.head())

# Procedures data
df_procedures = pd.read_csv("procedures.csv")
print("=== Procedures Data ===")
display(df_procedures.head())

# Insurance data
df_insurance = pd.read_csv("insurance.csv")
print("=== Insurance Data ===")
display(df_insurance.head())
# Out:
# === Patients Data ===
#    Patient ID     Patient Name  Gender  Age  City ID      Race
# 0           1  Morgan Thompson    Male   18       10  Hispanic
# 1           2   Avery Anderson    Male   19       27  Hispanic
# 2           3       Aisha Khan  Female   20       10     Asian
# 3           4       Adanna Eze    Male   20        9     Black
# 4           5      Haruto Chen    Male   20        9     Asian
# === Providers Data ===
#    Provider ID     Provider Name  Gender Nationality  Age  \
# 0            1   Dr. Olu Abisola    Male    Nigerian   37
# 1            4    Dr. Ravi Patel    Male      Indian   45
# 2            2  Dr. Johnson Grek    Male    European   50
# 3            3    Dr. Emma Jones  Female    European   34
# 4            5  Dr. Sade Kikiola  Female    Nigerian   35
#
#                              Image
# 0  https://i.imgur.com/eG4Tcam.png
# 1  https://i.imgur.com/0cmrpb3.png
# 2  https://i.imgur.com/HWj2RL5.png
# 3  https://i.imgur.com/hgIjY62.png
# 4  https://i.imgur.com/3sep9QD.png
# === Visits Data ===
#   Date of Visit  Patient ID  Provider ID  Department ID  Diagnosis ID  \
# 0      1/1/2024        4928            1              2             1
# 1      1/1/2024        1083            4              1             4
# 2      1/1/2024        4534            4              2             1
# 3      1/1/2024        4504            4              1             4
# 4      1/1/2024         331            4              2             1
#
#    Procedure ID  Insurance ID Service Type  Treatment Cost  Medication Cost  \
# 0             2             1   Outpatient             841               21
# 1             2             2    Inpatient             535               27
# 2             2             2    Inpatient             422               70
# 3             4             3   Outpatient             811              136
# 4             2             3   Outpatient             682              131
#
#   Follow-Up Visit Date  Patient Satisfaction Score     Referral Source  \
# 0             1/9/2024                           7       Self-Referral
# 1                  NaN                           8           Emergency
# 2                  NaN                           7       Self-Referral
# 3            1/20/2024                           5       Self-Referral
# 4            1/30/2024                           5  Physician Referral
#
#   Emergency Visit Payment Status Discharge Date Admitted Date  \
# 0              No           Paid            NaN           NaN
# 1              No           Paid            NaN           NaN
# 2              No           Paid            NaN           NaN
# 3              No           Paid            NaN           NaN
# 4              No           Paid            NaN           NaN
#
#            Room Type  Insurance Coverage  Room Charges(daily rate)
# 0                NaN               603.4                         0
# 1  Semi-Private Room               414.4                        30
# 2  Semi-Private Room               365.4                        30
# 3                NaN                 NaN                         0
# 4                NaN                 NaN                         0
# === Cities Data ===
#    City ID        City             State
# 0       40   Sheffield             Wales
# 1        9   Edinburgh           England
# 2        2  Birmingham  Northern Ireland
# 3       13     Glasgow           England
# 4       37   Sheffield           England
# === Departments Data ===
#    Department ID       Department
# 0              2  General Surgery
# 1              1       Cardiology
# 2              3        Neurology
# 3              5       Pediatrics
# 4              4      Orthopedics
# === Diagnoses Data ===
#    Diagnosis ID     Diagnosis
# 0             1  Appendicitis
# 1             4  Hypertension
# 2             2        Asthma
# 3             5      Migraine
# 4             3      Fracture
# === Procedures Data ===
#    Procedure ID   Procedure
# 0             2     CT Scan
# 1             5       X-Ray
# 2             4  Ultrasound
# 3             1  Blood Test
# 4             3    MRI Scan
# === Insurance Data ===
#    Insurance ID Insurance Provider
# 0             1              Aviva
# 1             2                AXA
# 2             3            Allianz

# %%
# Patients
print("=== Patients Data Types ===")
print(df_patients.dtypes)
print("\n")
# Out:
# === Patients Data Types ===
# Patient ID       int64
# Patient Name    object
# Gender          object
# Age              int64
# City ID          int64
# Race            object
# dtype: object

# %%
# Providers
print("=== Providers Data Types ===")
print(df_providers.dtypes)
print("\n")
# Out:
# === Providers Data Types ===
# Provider ID       int64
# Provider Name    object
# Gender           object
# Nationality      object
# Age               int64
# Image            object
# dtype: object

# %%
# Visits
print("=== Visits Data Types ===")
print(df_visits.dtypes)
print("\n")
# Out:
# === Visits Data Types ===
# Date of Visit                  object
# Patient ID                      int64
# Provider ID                     int64
# Department ID                   int64
# Diagnosis ID                    int64
# Procedure ID                    int64
# Insurance ID                    int64
# Service Type                   object
# Treatment Cost                  int64
# Medication Cost                 int64
# Follow-Up Visit Date           object
# Patient Satisfaction Score      int64
# Referral Source                object
# Emergency Visit                object
# Payment Status                 object
# Discharge Date                 object
# Admitted Date                  object
# Room Type                      object
# Insurance Coverage            float64
# Room Charges(daily rate)        int64
# dtype: object

# %%
# Cities
print("=== Cities Data Types ===")
print(df_cities.dtypes)
print("\n")
# Out:
# === Cities Data Types ===
# City ID     int64
# City       object
# State      object
# dtype: object

# %%
# Departments
print("=== Departments Data Types ===")
print(df_departments.dtypes)
print("\n")
# Out:
# === Departments Data Types ===
# Department ID     int64
# Department       object
# dtype: object

# %%
# Diagnoses
print("=== Diagnoses Data Types ===")
print(df_diagnoses.dtypes)
print("\n")
# Out:
# === Diagnoses Data Types ===
# Diagnosis ID     int64
# Diagnosis       object
# dtype: object

# %%
# Procedures
print("=== Procedures Data Types ===")
print(df_procedures.dtypes)
print("\n")
# Out:
# === Procedures Data Types ===
# Procedure ID     int64
# Procedure       object
# dtype: object

# %%
# Insurance
print("=== Insurance Data Types ===")
print(df_insurance.dtypes)
print("\n")
# Out:
# === Insurance Data Types ===
# Insurance ID           int64
# Insurance Provider    object
# dtype: object

# %%
print(df_diagnoses.columns)
# Out:
# Index(['Diagnosis ID', 'Diagnosis'], dtype='object')

# %%
# Dictionary of datasets for easy reference
datasets = {
    "Patients": df_patients,
    "Providers": df_providers,
    "Cities": df_cities,
    "Departments": df_departments,
    "Insurance": df_insurance
}

# Start with Fact table (Visits)
df_fact = df_visits.copy()

# Merge dimensions one by one
df_fact = pd.merge(df_fact, df_patients, on="Patient ID", how="left")
df_fact = pd.merge(df_fact, df_providers, on="Provider ID", how="left")
df_fact = pd.merge(df_fact, df_cities, on="City ID", how="left")
df_fact = pd.merge(df_fact, df_departments, on="Department ID", how="left")
df_fact = pd.merge(df_fact, df_insurance, on="Insurance ID", how="left")

print("=== Fact Table Shape ===")
print(df_fact.shape)
display(df_fact.head())

# Diagnoses and Procedures are independent dimensions (no Visit ID in them)
print("=== Diagnoses Columns ===")
print(df_diagnoses.columns)

print("=== Procedures Columns ===")
print(df_procedures.columns)
# Out:
# === Fact Table Shape ===
# (5000, 34)
#   Date of Visit  Patient ID  Provider ID  Department ID  Diagnosis ID  \
# 0      1/1/2024        4928            1              2             1
# 1      1/1/2024        1083            4              1             4
# 2      1/1/2024        4534            4              2             1
# 3      1/1/2024        4504            4              1             4
# 4      1/1/2024         331            4              2             1
#
#    Procedure ID  Insurance ID Service Type  Treatment Cost  Medication Cost  \
# 0             2             1   Outpatient             841               21
# 1             2             2    Inpatient             535               27
# 2             2             2    Inpatient             422               70
# 3             4             3   Outpatient             811              136
# 4             2             3   Outpatient             682              131
#
#    ...      Race    Provider Name Gender_y Nationality Age_y  \
# 0  ...     Black  Dr. Olu Abisola     Male    Nigerian    37
# 1  ...     White   Dr. Ravi Patel     Male      Indian    45
# 2  ...  Hispanic   Dr. Ravi Patel     Male      Indian    45
# 3  ...     Asian   Dr. Ravi Patel     Male      Indian    45
# 4  ...     Black   Dr. Ravi Patel     Male      Indian    45
#
#                              Image       City    State       Department  \
# 0  https://i.imgur.com/eG4Tcam.png  Sheffield    Wales  General Surgery
# 1  https://i.imgur.com/0cmrpb3.png  Edinburgh  England       Cardiology
# 2  https://i.imgur.com/0cmrpb3.png  Sheffield    Wales  General Surgery
# 3  https://i.imgur.com/0cmrpb3.png  Edinburgh  England       Cardiology
# 4  https://i.imgur.com/0cmrpb3.png  Sheffield    Wales  General Surgery
#
#    Insurance Provider
# 0               Aviva
# 1                 AXA
# 2                 AXA
# 3             Allianz
# 4             Allianz
#
# [5 rows x 34 columns]
# === Diagnoses Columns ===
# Index(['Diagnosis ID', 'Diagnosis'], dtype='object')
# === Procedures Columns ===
# Index(['Procedure ID', 'Procedure'], dtype='object')

# %%
# Start with Visits as Fact table
df_fact = df_visits.copy()

# Join with Patients
df_fact = pd.merge(df_fact, df_patients, on="Patient ID", how="left")

# Join with Providers
df_fact = pd.merge(df_fact, df_providers, on="Provider ID", how="left")

# Join with Cities
df_fact = pd.merge(df_fact, df_cities, on="City ID", how="left")

# Join with Departments
df_fact = pd.merge(df_fact, df_departments, on="Department ID", how="left")

# Join with Insurance
df_fact = pd.merge(df_fact, df_insurance, on="Insurance ID", how="left")

# Join with Diagnoses
df_fact = pd.merge(df_fact, df_diagnoses, on="Diagnosis ID", how="left")

# Join with Procedures
df_fact = pd.merge(df_fact, df_procedures, on="Procedure ID", how="left")

print("=== Final Fact Table ===")
print(df_fact.head())
# Out:
# === Final Fact Table ===
#   Date of Visit  Patient ID  Provider ID  Department ID  Diagnosis ID  \
# 0      1/1/2024        4928            1              2             1
# 1      1/1/2024        1083            4              1             4
# 2      1/1/2024        4534            4              2             1
# 3      1/1/2024        4504            4              1             4
# 4      1/1/2024         331            4              2             1
#
#    Procedure ID  Insurance ID Service Type  Treatment Cost  Medication Cost  \
# 0             2             1   Outpatient             841               21
# 1             2             2    Inpatient             535               27
# 2             2             2    Inpatient             422               70
# 3             4             3   Outpatient             811              136
# 4             2             3   Outpatient             682              131
#
#    ... Gender_y  Nationality Age_y                            Image  \
# 0  ...     Male     Nigerian    37  https://i.imgur.com/eG4Tcam.png
# 1  ...     Male       Indian    45  https://i.imgur.com/0cmrpb3.png
# 2  ...     Male       Indian    45  https://i.imgur.com/0cmrpb3.png
# 3  ...     Male       Indian    45  https://i.imgur.com/0cmrpb3.png
# 4  ...     Male       Indian    45  https://i.imgur.com/0cmrpb3.png
#
#         City    State       Department Insurance Provider     Diagnosis  \
# 0  Sheffield    Wales  General Surgery              Aviva  Appendicitis
# 1  Edinburgh  England       Cardiology                AXA  Hypertension
# 2  Sheffield    Wales  General Surgery                AXA  Appendicitis
# 3  Edinburgh  England       Cardiology            Allianz  Hypertension
# 4  Sheffield    Wales  General Surgery            Allianz  Appendicitis
#
#     Procedure
# 0     CT Scan
# 1     CT Scan
# 2     CT Scan
# 3  Ultrasound
# 4     CT Scan
#
# [5 rows x 36 columns]

# %%
# Basic Exploration for Cleaning Needs
print("=== Shape of Fact Table ===")
print(df_fact.shape)

print("\n=== Missing Values ===")
print(df_fact.isnull().sum())

print("\n=== Duplicated Rows ===")
print(df_fact.duplicated().sum())

print("\n=== Data Types ===")
print(df_fact.dtypes)

print("\n=== Summary Statistics (Numerical Columns) ===")
print(df_fact.describe())

print("\n=== Unique Values in Categorical Columns ===")
for col in df_fact.select_dtypes(include='object').columns:
    print(f"{col}: {df_fact[col].nunique()} unique values")
# Out:
# === Shape of Fact Table ===
# (5000, 36)
#
# === Missing Values ===
# Date of Visit                    0
# Patient ID                       0
# Provider ID                      0
# Department ID                    0
# Diagnosis ID                     0
# Procedure ID                     0
# Insurance ID                     0
# Service Type                     0
# Treatment Cost                   0
# Medication Cost                  0
# Follow-Up Visit Date          2493
# Patient Satisfaction Score       0
# Referral Source                  0
# Emergency Visit                  0
# Payment Status                   0
# Discharge Date                3768
# Admitted Date                 3768
# Room Type                     2507
# Insurance Coverage             119
# Room Charges(daily rate)         0
# Patient Name                     0
# Gender_x                         0
# Age_x                            0
# City ID                          0
# Race                             0
# Provider Name                    0
# Gender_y                         0
# Nationality                      0
# Age_y                            0
# Image                            0
# City                             0
# State                            0
# Department                       0
# Insurance Provider               0
# Diagnosis                        0
# Procedure                        0
# dtype: int64
#
# === Duplicated Rows ===
# 0
#
# === Data Types ===
# Date of Visit                  object
# Patient ID                      int64
# Provider ID                     int64
# Department ID                   int64
# Diagnosis ID                    int64
# Procedure ID                    int64
# Insurance ID                    int64
# Service Type                   object
# Treatment Cost                  int64
# Medication Cost                 int64
# Follow-Up Visit Date           object
# Patient Satisfaction Score      int64
# Referral Source                object
# Emergency Visit                object
# Payment Status                 object
# Discharge Date                 object
# Admitted Date                  object
# Room Type                      object
# Insurance Coverage            float64
# Room Charges(daily rate)        int64
# Patient Name                   object
# Gender_x                       object
# Age_x                           int64
# City ID                         int64
# Race                           object
# Provider Name                  object
# Gender_y                       object
# Nationality                    object
# Age_y                           int64
# Image                          object
# City                           object
# State                          object
# Department                     object
# Insurance Provider             object
# Diagnosis                      object
# Procedure                      object
# dtype: object
#
# === Summary Statistics (Numerical Columns) ===
#         Patient ID  Provider ID  Department ID  Diagnosis ID  Procedure ID  \
# count  5000.000000  5000.000000    5000.000000    5000.00000   5000.000000
# mean   2487.617200     3.288800       2.749600       3.00900      3.273000
# std    1435.369134     1.662392       1.400604       1.32547      1.422841
# min       1.000000     1.000000       1.000000       1.00000      1.000000
# 25%    1244.750000     1.000000       1.000000       2.00000      2.000000
# 50%    2489.500000     4.000000       3.000000       3.00000      3.000000
# 75%    3731.250000     5.000000       4.000000       4.00000      5.000000
# max    4973.000000     5.000000       5.000000       5.00000      5.000000
#
#        Insurance ID  Treatment Cost  Medication Cost  \
# count   5000.000000     5000.000000      5000.000000
# mean       1.994000      526.081200       109.207800
# std        0.813447      276.548485        52.001229
# min        1.000000       50.000000        20.000000
# 25%        1.000000      284.000000        64.000000
# 50%        2.000000      525.000000       109.000000
# 75%        3.000000      765.000000       154.000000
# max        3.000000     1000.000000       199.000000
#
#        Patient Satisfaction Score  Insurance Coverage  \
# count                 5000.000000         4881.000000
# mean                     3.840400          456.038455
# std                      2.941064          196.993058
# min                      1.000000           55.300000
# 25%                      1.000000          286.300000
# 50%                      2.000000          456.400000
# 75%                      6.000000          625.100000
# max                     10.000000          858.200000
#
#        Room Charges(daily rate)        Age_x      City ID        Age_y
# count               5000.000000  5000.000000  5000.000000  5000.000000
# mean                  14.634000    48.805600    16.021400    38.494800
# std                   18.678753    17.906991    12.254019     5.108463
# min                    0.000000    18.000000     1.000000    34.000000
# 25%                    0.000000    34.000000     6.000000    35.000000
# 50%                    0.000000    49.000000    10.000000    37.000000
# 75%                   30.000000    64.000000    25.000000    45.000000
# max                   50.000000    79.000000    40.000000    50.000000
#
# === Unique Values in Categorical Columns ===
# Date of Visit: 439 unique values
# Service Type: 3 unique values
# Follow-Up Visit Date: 514 unique values
# Referral Source: 3 unique values
# Emergency Visit: 2 unique values
# Payment Status: 2 unique values
# Discharge Date: 250 unique values
# Admitted Date: 249 unique values
# Room Type: 3 unique values
# Patient Name: 400 unique values
# Gender_x: 2 unique values
# Race: 5 unique values
# Provider Name: 5 unique values
# Gender_y: 2 unique values
# Nationality: 3 unique values
# Image: 5 unique values
# City: 10 unique values
# State: 4 unique values
# Department: 5 unique values
# Insurance Provider: 3 unique values
# Diagnosis: 5 unique values
# Procedure: 5 unique values

# %%
#  Rename age and gender columns

df_fact = df_fact.rename(columns={
    "Age_x": "Patient Age",
    "Gender_x": "Patient Gender",
    "Age_y": "Provider Age",
    "Gender_y": "Provider Gender"
})

print(df_fact[["Patient Age", "Patient Gender", "Provider Age", "Provider Gender"]].head())
# Out:
#    Patient Age Patient Gender  Provider Age Provider Gender
# 0           56           Male            37            Male
# 1           69         Female            45            Male
# 2           46         Female            45            Male
# 3           32         Female            45            Male
# 4           60         Female            45            Male

# %%
# Patients Cleaning
df_patients_clean = df_patients.copy()

# Rename columns for clarity (optional)
df_patients_clean = df_patients_clean.rename(columns={
    "Age": "Patient Age",
    "Gender": "Patient Gender"
})

# Drop duplicates
df_patients_clean = df_patients_clean.drop_duplicates()

# Handle missing values
df_patients_clean["Patient Age"] = df_patients_clean["Patient Age"].fillna(df_patients_clean["Patient Age"].median())

print("=== Patients Cleaned ===")
print(df_patients_clean.info())
# Out:
# === Patients Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4973 entries, 0 to 4972
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient ID      4973 non-null   int64
#  1   Patient Name    4973 non-null   object
#  2   Patient Gender  4973 non-null   object
#  3   Patient Age     4973 non-null   int64
#  4   City ID         4973 non-null   int64
#  5   Race            4973 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 233.2+ KB
# None

# %%
# Providers Cleaning
df_providers_clean = df_providers.copy()

# Rename columns
df_providers_clean = df_providers_clean.rename(columns={
    "Age": "Provider Age",
    "Gender": "Provider Gender"
})

# Drop duplicates
df_providers_clean = df_providers_clean.drop_duplicates()

print("=== Providers Cleaned ===")
print(df_providers_clean.info())
# Out:
# === Providers Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Provider ID      5 non-null      int64
#  1   Provider Name    5 non-null      object
#  2   Provider Gender  5 non-null      object
#  3   Nationality      5 non-null      object
#  4   Provider Age     5 non-null      int64
#  5   Image            5 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 372.0+ bytes
# None

# %%
# Visits Cleaning
df_visits_clean = df_visits.copy()

# Convert date columns
date_cols = ["Date of Visit", "Follow-Up Visit Date", "Discharge Date", "Admitted Date"]
for col in date_cols:
    df_visits_clean[col] = pd.to_datetime(df_visits_clean[col], errors="coerce")

# Fill missing Insurance Coverage
df_visits_clean["Insurance Coverage"] = df_visits_clean["Insurance Coverage"].fillna(df_visits_clean["Insurance Coverage"].median())

# Keep negative costs out
num_cols = ["Treatment Cost", "Medication Cost", "Room Charges(daily rate)", "Insurance Coverage"]
for col in num_cols:
    df_visits_clean = df_visits_clean[df_visits_clean[col] >= 0]

print("=== Visits Cleaned ===")
print(df_visits_clean.info())
# Out:
# === Visits Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date of Visit               5000 non-null   datetime64[ns]
#  1   Patient ID                  5000 non-null   int64
#  2   Provider ID                 5000 non-null   int64
#  3   Department ID               5000 non-null   int64
#  4   Diagnosis ID                5000 non-null   int64
#  5   Procedure ID                5000 non-null   int64
#  6   Insurance ID                5000 non-null   int64
#  7   Service Type                5000 non-null   object
#  8   Treatment Cost              5000 non-null   int64
#  9   Medication Cost             5000 non-null   int64
#  10  Follow-Up Visit Date        2507 non-null   datetime64[ns]
#  11  Patient Satisfaction Score  5000 non-null   int64
#  12  Referral Source             5000 non-null   object
#  13  Emergency Visit             5000 non-null   object
#  14  Payment Status              5000 non-null   object
#  15  Discharge Date              1232 non-null   datetime64[ns]
#  16  Admitted Date               1232 non-null   datetime64[ns]
#  17  Room Type                   2493 non-null   object
#  18  Insurance Coverage          5000 non-null   float64
#  19  Room Charges(daily rate)    5000 non-null   int64
# dtypes: datetime64[ns](4), float64(1), int64(10), object(5)
# memory usage: 781.4+ KB
# None

# %%
# Cities Cleaning
df_cities_clean = df_cities.copy()

# Drop duplicates
df_cities_clean = df_cities_clean.drop_duplicates()

print("=== Cities Cleaned ===")
print(df_cities_clean.info())
# Out:
# === Cities Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City ID  40 non-null     int64
#  1   City     40 non-null     object
#  2   State    40 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB
# None

# %%
# Departments Cleaning
df_departments_clean = df_departments.copy()

# Drop duplicates
df_departments_clean = df_departments_clean.drop_duplicates()

print("=== Departments Cleaned ===")
print(df_departments_clean.info())
# Out:
# === Departments Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Department ID  5 non-null      int64
#  1   Department     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes
# None

# %%
# Insurance Cleaning
df_insurance_clean = df_insurance.copy()

# Drop duplicates
df_insurance_clean = df_insurance_clean.drop_duplicates()

print("=== Insurance Cleaned ===")
print(df_insurance_clean.info())
# Out:
# === Insurance Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Insurance ID        3 non-null      int64
#  1   Insurance Provider  3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
# None

# %%
# Diagnoses Cleaning
df_diagnoses_clean = df_diagnoses.copy()

# Drop duplicates
df_diagnoses_clean = df_diagnoses_clean.drop_duplicates()

print("=== Diagnoses Cleaned ===")
print(df_diagnoses_clean.info())
# Out:
# === Diagnoses Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Diagnosis ID  5 non-null      int64
#  1   Diagnosis     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes
# None

# %%
# Procedures Cleaning
df_procedures_clean = df_procedures.copy()

# Drop duplicates
df_procedures_clean = df_procedures_clean.drop_duplicates()

print("=== Procedures Cleaned ===")
print(df_procedures_clean.info())
# Out:
# === Procedures Cleaned ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Procedure ID  5 non-null      int64
#  1   Procedure     5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes
# None

# %%
# keep original data
df_visits_original = df_visits.copy()

# cleaning steps
df_visits_clean = df_visits_original.copy()

# %%
# reload the original csv file to get back all values (including negatives)
df_visits_clean = pd.read_csv("/content/visits.csv")

# %%
# 1:Departments generate the highest treatment revenue
df_fact.groupby("Department")["Treatment Cost"].sum().sort_values(ascending=False)
# Out:
# Department
# Cardiology         681048
# Orthopedics        622560
# General Surgery    622260
# Neurology          371453
# Pediatrics         333085
# Name: Treatment Cost, dtype: int64

# %%
# 2:Average patient satisfaction score per doctor
df_fact.groupby("Provider Name")["Patient Satisfaction Score"].mean().sort_values(ascending=False)
# Out:
# Provider Name
# Dr. Olu Abisola     5.448454
# Dr. Johnson Grek    5.047191
# Dr. Emma Jones      4.852248
# Dr. Ravi Patel      3.364912
# Dr. Sade Kikiola    2.354133
# Name: Patient Satisfaction Score, dtype: float64

# %%
# 3:Insurance providers covering the most expensive procedures
df_fact.groupby("Insurance Provider")["Procedure ID"].count().sort_values(ascending=False)
# Out:
# Insurance Provider
# AXA        1692
# Aviva      1669
# Allianz    1639
# Name: Procedure ID, dtype: int64

# %%
# 4:Readmission rate (patients returning for follow-up visits)
readmission_rate = df_fact["Follow-Up Visit Date"].notna().mean()
print("Readmission Rate:", readmission_rate)
# Out:
# Readmission Rate: 0.5014

# %%
# 5: Most common diagnoses in emergency visits
df_fact[df_fact["Emergency Visit"] == "Yes"]["Diagnosis"].value_counts()
# Out:
# Diagnosis
# Hypertension    804
# Asthma          384
# Appendicitis    334
# Fracture        211
# Migraine        196
# Name: count, dtype: int64

# %%
# 6: Distribution of treatment costs by city
df_fact.groupby("City")["Treatment Cost"].sum().sort_values(ascending=False)
# Out:
# City
# Edinburgh     784134
# Birmingham    624567
# Sheffield     317687
# Glasgow       141009
# Leeds         138228
# Liverpool     132942
# London        128065
# Bristol       125249
# Manchester    120991
# Newcastle     117534
# Name: Treatment Cost, dtype: int64

# %%
# 7: Effect of patient age on satisfaction scores
df_fact.groupby("Patient Age")["Patient Satisfaction Score"].mean()
# Out:
# Patient Age
# 18    3.831169
# 19    4.372093
# 20    4.024691
# 21    3.792683
# 22    3.848101
#         ...
# 75    4.036145
# 76    3.556962
# 77    4.460784
# 78    3.779221
# 79    3.263158
# Name: Patient Satisfaction Score, Length: 62, dtype: float64

# %%
# 8: Doctors handling the highest number of patients
df_fact.groupby("Provider Name")["Patient ID"].count().sort_values(ascending=False)
# Out:
# Provider Name
# Dr. Sade Kikiola    1875
# Dr. Olu Abisola     1358
# Dr. Ravi Patel       855
# Dr. Emma Jones       467
# Dr. Johnson Grek     445
# Name: Patient ID, dtype: int64

# %%
# 9: Percentage of visits resulting in hospital admission
hospital_admission_rate = df_fact["Admitted Date"].notna().mean()
print("Hospital Admission Rate:", hospital_admission_rate)
# Out:
# Hospital Admission Rate: 0.2464

# %%
# 10: What is the average treatment cost for each service type
df_fact.groupby("Service Type")["Treatment Cost"].mean().sort_values(ascending=False)
# Out:
# Service Type
# Inpatient     534.368675
# Outpatient    525.456746
# Emergency     519.000810
# Name: Treatment Cost, dtype: float64

# %%
# 1 Departments revenue
dept_revenue = df_fact.groupby("Department")["Treatment Cost"].sum().sort_values(ascending=False)
plt.figure(figsize=(8,5))
sns.barplot(x=dept_revenue.index, y=dept_revenue.values, palette="Blues_d")
plt.title("Total Treatment Revenue by Department")
plt.ylabel("Revenue")
plt.xlabel("Department")
plt.show()
# Out:
# /tmp/ipython-input-4046701819.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dept_revenue.index, y=dept_revenue.values, palette="Blues_d")

# %%
# 2 Distribution of Patient Ages
plt.figure(figsize=(8,5))
sns.histplot(df_fact["Patient Age"], bins=20, kde=True, color="skyblue")
plt.title("Distribution of Patient Ages")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# 3 Monthly Visits Trend
df_fact["Visit Month"] = pd.to_datetime(df_fact["Date of Visit"]).dt.to_period("M")
monthly_visits = df_fact.groupby("Visit Month")["Patient ID"].count()
plt.figure(figsize=(10,5))
monthly_visits.plot(kind="line", marker="o", color="green")
plt.title("Monthly Visits Trend")
plt.xlabel("Month")
plt.ylabel("Number of Visits")
plt.grid(True)
plt.show()

# %%
# 4 Top 10 Diagnoses
top_diag = df_fact["Diagnosis"].value_counts().head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_diag.index, y=top_diag.values, palette="Reds_d")
plt.title("Top 10 Diagnoses")
plt.xticks(rotation=45)
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-2162187038.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_diag.index, y=top_diag.values, palette="Reds_d")

# %%
# 5 Average Room Charges by City
room_charges_city = df_fact.groupby("City")["Room Charges(daily rate)"].mean().sort_values(ascending=False)
plt.figure(figsize=(10,5))
sns.barplot(x=room_charges_city.index, y=room_charges_city.values, palette="coolwarm")
plt.title("Average Room Charges by City")
plt.xticks(rotation=45)
plt.ylabel("Avg Room Charge")
plt.show()
# Out:
# /tmp/ipython-input-3275784119.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=room_charges_city.index, y=room_charges_city.values, palette="coolwarm")

# %%
# 6 Readmission Rate by Age Group
df_fact["Age Group"] = pd.cut(df_fact["Patient Age"], bins=[0,18,30,45,60,80], labels=["<18","18-30","31-45","46-60","61-80"])
readmit_age = df_fact.groupby("Age Group")["Follow-Up Visit Date"].apply(lambda x: x.notna().mean())
plt.figure(figsize=(8,5))
sns.barplot(x=readmit_age.index, y=readmit_age.values, palette="Set2")
plt.title("Readmission Rate by Age Group")
plt.ylabel("Rate")
plt.show()
# Out:
# /tmp/ipython-input-484358982.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   readmit_age = df_fact.groupby("Age Group")["Follow-Up Visit Date"].apply(lambda x: x.notna().mean())
# /tmp/ipython-input-484358982.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=readmit_age.index, y=readmit_age.values, palette="Set2")

# %%
# 7 Patient Satisfaction Over Time
satisfaction_trend = df_fact.groupby("Visit Month")["Patient Satisfaction Score"].mean()
plt.figure(figsize=(10,5))
satisfaction_trend.plot(kind="line", marker="o", color="purple")
plt.title("Patient Satisfaction Over Time")
plt.xlabel("Month")
plt.ylabel("Avg Satisfaction Score")
plt.grid(True)
plt.show()

# %%
# 8 Top 10 Diagnoses
top_diag = df_fact["Diagnosis"].value_counts().head(10)

plt.figure(figsize=(8,8))
plt.pie(
    top_diag.values,
    labels=top_diag.index,
    autopct="%1.1f%%",
    startangle=140,
    colors=plt.cm.viridis.colors
)

plt.title("Top 10 Diagnoses Distribution", fontsize=14)
plt.show()
